# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import numpy as np
import pandas as pd
from music21 import converter, instrument, note, chord
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import SimpleRNN
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.layers import Masking
from keras.layers import Embedding
from keras.layers import Bidirectional
from keras.layers import LSTM, ConvLSTM2D
from keras.layers import Input
from keras.utils import np_utils
from keras.callbacks import History
from tensorflow.keras import optimizers
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
hist = History()

# %%
def categorical(arr, n_vocab):
    out = np.zeros((len(arr), n_vocab), dtype=int)
    for ind, value in enumerate(arr):
        out[ind, value] = 1
    return out

# %%
def most_frequent(List):
    while(1):
        com = max(set(List), key = List.count)
        if max(set(List), key = List.count) > 400:
            temp = []
            for i in List:
                if i < 400:
                    temp += [i]
            List = temp
        else:
            return com

# %%
def prepare_sequences(notes_train, notes_val, notes_test, n_vocab):
    pitchnames = set(item for item in notes_train).union(set((item for item in notes_val))).union(set(item for item in notes_test))
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
    sequence_length = 100
    train_input = []
    train_output = []
    for i in range(0, len(notes_train) - sequence_length, sequence_length + 1):
        train_input_temp = []
        sequence_in = notes_train[i:i + sequence_length]
        sequence_out = notes_train[i + sequence_length]
        train_input_temp = [note_to_int[char] for char in sequence_in]
        common = most_frequent(train_input_temp)
        temp_1 = []
        for note in sequence_in:
            if note_to_int[note] >= 400:
                temp_1 += [common]
            else:
                temp_1 += [note_to_int[note]]
        train_input.append(temp_1)
        if note_to_int[sequence_out] >= 400:
            train_output.append(common)
        else:
            train_output.append(note_to_int[sequence_out])
    n_patterns = len(train_input)
    train_input = np.reshape(train_input, (n_patterns, sequence_length, 1))
    train_output = categorical(train_output, 400)

    val_input = []
    val_output = []
    for i in range(0, len(notes_val) - sequence_length, sequence_length + 1):
        sequence_in = notes_val[i:i + sequence_length]
        sequence_out = notes_val[i + sequence_length]
        val_input_temp = [note_to_int[char] for char in sequence_in]
        common = most_frequent(val_input_temp)
        temp_1 = []
        for note in sequence_in:
            if note_to_int[note] >= 400:
                temp_1 += [common]
            else:
                temp_1 += [note_to_int[note]]
        val_input.append(temp_1)
        if note_to_int[sequence_out] >= 400:
            val_output.append(common)
        else:
            val_output.append(note_to_int[sequence_out])
    n_patterns = len(val_input)
    val_input = np.reshape(val_input, (n_patterns, sequence_length, 1))
    val_output = categorical(val_output, 400)

    n_vocab_temp = len(set(notes_train).union(set(notes_val).union(set(notes_test))))
    with open('/content/drive/My Drive/nes/bindings', 'wb') as f:
        pickle.dump(note_to_int, f)

    return (train_input, train_output, val_input, val_output)

# %%
def create_network(network_input, n_vocab):
    model = Sequential()
    model.add(SimpleRNN(512, input_shape=(network_input.shape[1], network_input.shape[2]), return_sequences=True))
    model.add(SimpleRNN(512, return_sequences=True, recurrent_dropout=0.5))
    model.add(SimpleRNN(512, return_sequences=True, recurrent_dropout=0.5))
    model.add(SimpleRNN(512, recurrent_dropout=0.9))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))
    model.add(BatchNorm())
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def create_network_1(network_input, n_vocab):
    model = Sequential()
    model.add(LSTM(256,input_shape=(network_input.shape[1], network_input.shape[2]), return_sequences=True, recurrent_dropout=0.3))
    model.add(LSTM(128, return_sequences=True, recurrent_dropout=0.3))
    model.add(LSTM(128, return_sequences=True, recurrent_dropout=0.3))
    model.add(LSTM(128, recurrent_dropout=0.3))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))
    model.add(BatchNorm())
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    optimizer = optimizers.Adam(clipvalue=0.5)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
with open('/content/drive/My Drive/nes/train_notes', 'rb') as f:
    notes_train = pickle.load(f)

with open('/content/drive/My Drive/nes/val_notes', 'rb') as f:
    notes_val = pickle.load(f)

with open('/content/drive/My Drive/nes/test_notes', 'rb') as f:
    notes_test = pickle.load(f)

train = []
for i in notes_train:
    if len(i) > 101:
        train += i[:101]
notes_train = train

val = []
for i in notes_val:
    if len(i) > 101:
        val += i[:101]
notes_val = val

test = []
for i in notes_test:
    if len(i) > 110:
        test += i[:110]
notes_test = test

# %% [markdown]
# # Prep

# %%
n_vocab_temp = len(set(notes_train).union(set(notes_val).union(set(notes_test))))
network_input_train, network_output_train, network_input_val, network_output_val = prepare_sequences(notes_train, notes_val, notes_test, n_vocab_temp)

# %%
n_vocab = 400

# %%
network_input_train.shape
# Out:
# (2193, 100, 1)

# %%
network_input_val.shape
# Out:
# (161, 100, 1)

# %%
network_output_train.shape
# Out:
# (2193, 400)

# %%
network_output_val.shape
# Out:
# (161, 400)

# %%
n_vocab
# Out:
# 400

# %% [markdown]
# # LSTM 1

# %%
model = create_network_1(network_input_train, n_vocab)
filepath = "/content/drive/My Drive/nes/check/1/weights-{epoch:02d}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
print(model.summary())
hist = model.fit(network_input_train, network_output_train, epochs = 100,
            validation_data = (network_input_val, network_output_val), 
            batch_size = 128, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 100, 256)          264192
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 100, 128)          197120
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 128)          131584
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_7 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 400)               51600
# _________________________________________________________________
# activation_8 (Activation)    (None, 400)               0
# =================================================================
# Total params: 810,128
# Trainable params: 809,616
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 18/18 [==============================] - 51s 2s/step - loss: 6.0259 - accuracy: 0.0169 - val_loss: 5.9224 - val_accuracy: 0.0373
# Epoch 2/100
# 18/18 [==============================] - 40s 2s/step - loss: 5.6760 - accuracy: 0.0575 - val_loss: 5.7704 - val_accuracy: 0.0373
# Epoch 3/100
# 18/18 [==============================] - 41s 2s/step - loss: 5.3216 - accuracy: 0.0834 - val_loss: 5.5133 - val_accuracy: 0.0373
# Epoch 4/100
# 18/18 [==============================] - 40s 2s/step - loss: 4.9973 - accuracy: 0.0999 - val_loss: 5.2687 - val_accuracy: 0.1056
# Epoch 5/100
# 18/18 [==============================] - 40s 2s/step - loss: 4.7204 - accuracy: 0.0985 - val_loss: 4.9333 - val_accuracy: 0.0186
# Epoch 6/100
# 18/18 [==============================] - 40s 2s/step - loss: 4.5241 - accuracy: 0.1081 - val_loss: 4.5244 - val_accuracy: 0.0248
# Epoch 7/100
# 18/18 [==============================] - 39s 2s/step - loss: 4.2781 - accuracy: 0.1149 - val_loss: 4.1987 - val_accuracy: 0.0124
# Epoch 8/100
# 18/18 [==============================] - 40s 2s/step - loss: 4.0676 - accuracy: 0.1190 - val_loss: 3.8931 - val_accuracy: 0.0435
# Epoch 9/100
# 18/18 [==============================] - 41s 2s/step - loss: 3.8769 - accuracy: 0.1176 - val_loss: 3.8019 - val_accuracy: 0.0311
# Epoch 10/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.7402 - accuracy: 0.1140 - val_loss: 3.7070 - val_accuracy: 0.0373
# Epoch 11/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.5994 - accuracy: 0.1254 - val_loss: 3.6669 - val_accuracy: 0.0621
# Epoch 12/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.5179 - accuracy: 0.1245 - val_loss: 3.6439 - val_accuracy: 0.0683
# Epoch 13/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.4576 - accuracy: 0.1304 - val_loss: 3.6127 - val_accuracy: 0.0932
# Epoch 14/100
# 18/18 [==============================] - 39s 2s/step - loss: 3.4322 - accuracy: 0.1126 - val_loss: 3.5572 - val_accuracy: 0.1242
# Epoch 15/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.3836 - accuracy: 0.1190 - val_loss: 3.4927 - val_accuracy: 0.0807
# Epoch 16/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.3347 - accuracy: 0.1158 - val_loss: 3.5911 - val_accuracy: 0.0683
# Epoch 17/100
# 18/18 [==============================] - 39s 2s/step - loss: 3.3033 - accuracy: 0.1327 - val_loss: 3.4048 - val_accuracy: 0.1366
# Epoch 18/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.2774 - accuracy: 0.1290 - val_loss: 3.4249 - val_accuracy: 0.1118
# Epoch 19/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.3008 - accuracy: 0.1195 - val_loss: 3.4688 - val_accuracy: 0.1366
# Epoch 20/100
# 18/18 [==============================] - 39s 2s/step - loss: 3.2599 - accuracy: 0.1295 - val_loss: 3.5426 - val_accuracy: 0.1242
# Epoch 21/100
# 18/18 [==============================] - 39s 2s/step - loss: 3.2578 - accuracy: 0.1309 - val_loss: 3.3841 - val_accuracy: 0.1056
# Epoch 22/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.2395 - accuracy: 0.1281 - val_loss: 3.3596 - val_accuracy: 0.0994
# Epoch 23/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.2388 - accuracy: 0.1259 - val_loss: 3.3357 - val_accuracy: 0.1491
# Epoch 24/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.2543 - accuracy: 0.1227 - val_loss: 3.4595 - val_accuracy: 0.0497
# Epoch 25/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.2053 - accuracy: 0.1227 - val_loss: 3.4513 - val_accuracy: 0.0497
# Epoch 26/100
# 18/18 [==============================] - 41s 2s/step - loss: 3.2171 - accuracy: 0.1259 - val_loss: 3.5264 - val_accuracy: 0.0621
# Epoch 27/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.1920 - accuracy: 0.1295 - val_loss: 3.3886 - val_accuracy: 0.1118
# Epoch 28/100
# 18/18 [==============================] - 40s 2s/step - loss: 3.1807 - accuracy: 0.1350 - val_loss: 3.4004 - val_accuracy: 0.1429
# Epoch 29/100
100
# 18/18 [==============================] - 40s 2s/step - loss: 2.6808 - accuracy: 0.2134 - val_loss: 3.3744 - val_accuracy: 0.1304
# Epoch 99/100
# 18/18 [==============================] - 41s 2s/step - loss: 2.7104 - accuracy: 0.2130 - val_loss: 3.4629 - val_accuracy: 0.1242
# Epoch 100/100
# 18/18 [==============================] - 40s 2s/step - loss: 2.6727 - accuracy: 0.2139 - val_loss: 3.4309 - val_accuracy: 0.1491

# %% [markdown]
# ## Plotting the graphs

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist.history.values())[0])
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.title('Training loss over 100 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist.history.values())[1])
plt.xlabel('epoch')
plt.ylabel('training accuracy')
plt.title('Training accuracy over 100 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist.history.values())[2])
plt.xlabel('epoch')
plt.ylabel('validation loss')
plt.title('Validation loss over 100 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist.history.values())[3])
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.title('Validation accuracy over 100 epochs')
plt.show()

# %% [markdown]
# #RNN 1

# %%
model = create_network(network_input_train, n_vocab)
filepath = "/content/drive/My Drive/nes/check/2/weights-{epoch:02d}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
print(model.summary())
hist_1 = model.fit(network_input_train, network_output_train, epochs = 100,
            validation_data = (network_input_val, network_output_val), 
            batch_size = 128, callbacks=callbacks_list)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_13 (SimpleRNN)    (None, 100, 512)          263168
# _________________________________________________________________
# simple_rnn_14 (SimpleRNN)    (None, 100, 512)          524800
# _________________________________________________________________
# simple_rnn_15 (SimpleRNN)    (None, 100, 512)          524800
# _________________________________________________________________
# simple_rnn_16 (SimpleRNN)    (None, 512)               524800
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_9 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_10 (Dense)             (None, 400)               205200
# _________________________________________________________________
# activation_10 (Activation)   (None, 400)               0
# =================================================================
# Total params: 2,572,176
# Trainable params: 2,570,128
# Non-trainable params: 2,048
# _________________________________________________________________
# None
# Epoch 1/100
# 18/18 [==============================] - 15s 616ms/step - loss: 6.4408 - accuracy: 0.0036 - val_loss: 5.9225 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 18/18 [==============================] - 10s 579ms/step - loss: 6.2006 - accuracy: 0.0155 - val_loss: 5.8848 - val_accuracy: 0.0248
# Epoch 3/100
# 18/18 [==============================] - 10s 570ms/step - loss: 5.9828 - accuracy: 0.0219 - val_loss: 5.7022 - val_accuracy: 0.0373
# Epoch 4/100
# 18/18 [==============================] - 10s 580ms/step - loss: 5.7515 - accuracy: 0.0324 - val_loss: 5.4098 - val_accuracy: 0.0373
# Epoch 5/100
# 18/18 [==============================] - 10s 574ms/step - loss: 5.3689 - accuracy: 0.0255 - val_loss: 4.9660 - val_accuracy: 0.0186
# Epoch 6/100
# 18/18 [==============================] - 10s 580ms/step - loss: 4.9239 - accuracy: 0.0447 - val_loss: 4.5308 - val_accuracy: 0.0248
# Epoch 7/100
# 18/18 [==============================] - 10s 568ms/step - loss: 4.5918 - accuracy: 0.0420 - val_loss: 4.2549 - val_accuracy: 0.0186
# Epoch 8/100
# 18/18 [==============================] - 10s 565ms/step - loss: 4.3573 - accuracy: 0.0492 - val_loss: 4.1489 - val_accuracy: 0.0186
# Epoch 9/100
# 18/18 [==============================] - 10s 583ms/step - loss: 4.2182 - accuracy: 0.0451 - val_loss: 4.1106 - val_accuracy: 0.0186
# Epoch 10/100
# 18/18 [==============================] - 10s 548ms/step - loss: 3.6706 - accuracy: 0.0734 - val_loss: 4.0580 - val_accuracy: 0.0559
# Epoch 89/100
# 18/18 [==============================] - 10s 544ms/step - loss: 3.6813 - accuracy: 0.0720 - val_loss: 4.0703 - val_accuracy: 0.0559
# Epoch 90/100
# 18/18 [==============================] - 10s 554ms/step - loss: 3.6802 - accuracy: 0.0707 - val_loss: 4.0705 - val_accuracy: 0.0559
# Epoch 91/100
# 18/18 [==============================] - 10s 540ms/step - loss: 3.6755 - accuracy: 0.0661 - val_loss: 4.0832 - val_accuracy: 0.0559
# Epoch 92/100
# 18/18 [==============================] - 10s 557ms/step - loss: 3.6700 - accuracy: 0.0657 - val_loss: 4.0653 - val_accuracy: 0.0559
# Epoch 93/100
# 18/18 [==============================] - 10s 545ms/step - loss: 3.6801 - accuracy: 0.0661 - val_loss: 4.0753 - val_accuracy: 0.0559
# Epoch 94/100
# 18/18 [==============================] - 10s 545ms/step - loss: 3.6810 - accuracy: 0.0711 - val_loss: 4.0638 - val_accuracy: 0.0559
# Epoch 95/100
# 18/18 [==============================] - 10s 542ms/step - loss: 3.6593 - accuracy: 0.0739 - val_loss: 4.0515 - val_accuracy: 0.0559
# Epoch 96/100
# 18/18 [==============================] - 10s 573ms/step - loss: 3.6866 - accuracy: 0.0634 - val_loss: 4.0545 - val_accuracy: 0.0559
# Epoch 97/100
# 18/18 [==============================] - 10s 547ms/step - loss: 3.6532 - accuracy: 0.0670 - val_loss: 4.0252 - val_accuracy: 0.0559
# Epoch 98/100
# 18/18 [==============================] - 10s 553ms/step - loss: 3.6566 - accuracy: 0.0684 - val_loss: 4.0113 - val_accuracy: 0.0559
# Epoch 99/100
# 18/18 [==============================] - 10s 551ms/step - loss: 3.6831 - accuracy: 0.0643 - val_loss: 4.0468 - val_accuracy: 0.0559
# Epoch 100/100
# 18/18 [==============================] - 10s 552ms/step - loss: 3.6699 - accuracy: 0.0702 - val_loss: 4.0514 - val_accuracy: 0.0559

# %% [markdown]
# ## Plotting Graphs

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_1.history.values())[0])
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.title('Training loss over 100 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_1.history.values())[1])
plt.xlabel('epoch')
plt.ylabel('training accuracy')
plt.title('Training accuracy over 100 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_1.history.values())[2])
plt.xlabel('epoch')
plt.ylabel('validation loss')
plt.title('Validation loss over 100 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_1.history.values())[3])
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.title('Validation accuracy over 100 epochs')
plt.show()

# %% [markdown]
# # Prep

# %%
def prepare_sequences_1(notes_train, notes_val, notes_test, n_vocab):
    pitchnames = set(item for item in notes_train).union(set((item for item in notes_val))).union(set(item for item in notes_test))
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
    sequence_length = 100
    train_input = []
    train_output = []
    for i in range(0, len(notes_train) - sequence_length,10):
        train_input_temp = []
        sequence_in = notes_train[i:i + sequence_length]
        sequence_out = notes_train[i + sequence_length]
        train_input_temp = [note_to_int[char] for char in sequence_in]
        common = most_frequent(train_input_temp)
        temp_1 = []
        for note in sequence_in:
            if note_to_int[note] >= 400:
                temp_1 += [common]
            else:
                temp_1 += [note_to_int[note]]
        train_input.append(temp_1)
        if note_to_int[sequence_out] >= 400:
            train_output.append(common)
        else:
            train_output.append(note_to_int[sequence_out])
    n_patterns = len(train_input)
    train_input = np.reshape(train_input, (n_patterns, sequence_length, 1))
    train_output = categorical(train_output, 400)

    val_input = []
    val_output = []
    for i in range(0, len(notes_val) - sequence_length, sequence_length + 1):
        sequence_in = notes_val[i:i + sequence_length]
        sequence_out = notes_val[i + sequence_length]
        val_input_temp = [note_to_int[char] for char in sequence_in]
        common = most_frequent(val_input_temp)
        temp_1 = []
        for note in sequence_in:
            if note_to_int[note] >= 400:
                temp_1 += [common]
            else:
                temp_1 += [note_to_int[note]]
        val_input.append(temp_1)
        if note_to_int[sequence_out] >= 400:
            val_output.append(common)
        else:
            val_output.append(note_to_int[sequence_out])
    n_patterns = len(val_input)
    val_input = np.reshape(val_input, (n_patterns, sequence_length, 1))
    val_output = categorical(val_output, 400)

    n_vocab_temp = len(set(notes_train).union(set(notes_val).union(set(notes_test))))
    with open('/content/drive/My Drive/nes/bindings', 'wb') as f:
        pickle.dump(note_to_int, f)

    return (train_input, train_output, val_input, val_output)

# %%
n_vocab_temp = len(set(notes_train).union(set(notes_val).union(set(notes_test))))
network_input_train, network_output_train, network_input_val, network_output_val = prepare_sequences_1(notes_train, notes_val, notes_test, n_vocab_temp)

# %%
n_vocab = 400

# %%
network_input_train.shape
# Out:
# (22140, 100, 1)

# %%
network_input_val.shape
# Out:
# (161, 100, 1)

# %%
network_output_train.shape
# Out:
# (22140, 400)

# %%
network_output_val.shape
# Out:
# (161, 400)

# %% [markdown]
# # LSTM 2

# %%
model = create_network_1(network_input_train, n_vocab)
filepath = "/content/drive/My Drive/nes/check/3/weights-{epoch:02d}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
print(model.summary())
hist_2 = model.fit(network_input_train, network_output_train, epochs = 20,
            validation_data = (network_input_val, network_output_val), 
            batch_size = 128, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 100, 256)          264192
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 100, 128)          197120
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 128)          131584
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_7 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dense_8 (Dense)              (None, 400)               51600
# _________________________________________________________________
# activation_8 (Activation)    (None, 400)               0
# =================================================================
# Total params: 810,128
# Trainable params: 809,616
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/20
# 173/173 [==============================] - 390s 2s/step - loss: 4.8128 - accuracy: 0.0795 - val_loss: 3.7329 - val_accuracy: 0.0435
# Epoch 2/20
# 173/173 [==============================] - 378s 2s/step - loss: 3.4862 - accuracy: 0.1020 - val_loss: 3.5451 - val_accuracy: 0.0621
# Epoch 3/20
# 173/173 [==============================] - 375s 2s/step - loss: 3.2973 - accuracy: 0.1101 - val_loss: 3.3679 - val_accuracy: 0.1242
# Epoch 4/20
# 173/173 [==============================] - 371s 2s/step - loss: 3.2309 - accuracy: 0.1111 - val_loss: 3.4378 - val_accuracy: 0.0932
# Epoch 5/20
# 173/173 [==============================] - 370s 2s/step - loss: 3.1724 - accuracy: 0.1200 - val_loss: 3.3696 - val_accuracy: 0.0745
# Epoch 6/20
# 173/173 [==============================] - 372s 2s/step - loss: 3.1383 - accuracy: 0.1213 - val_loss: 3.3368 - val_accuracy: 0.1242
# Epoch 7/20
# 173/173 [==============================] - 369s 2s/step - loss: 3.1107 - accuracy: 0.1294 - val_loss: 3.2398 - val_accuracy: 0.0870
# Epoch 8/20
# 173/173 [==============================] - 367s 2s/step - loss: 3.0930 - accuracy: 0.1262 - val_loss: 3.3026 - val_accuracy: 0.1242
# Epoch 9/20
# 173/173 [==============================] - 371s 2s/step - loss: 3.0774 - accuracy: 0.1336 - val_loss: 3.1859 - val_accuracy: 0.1304
# Epoch 10/20
# 173/173 [==============================] - 372s 2s/step - loss: 3.0536 - accuracy: 0.1326 - val_loss: 3.2497 - val_accuracy: 0.0870
# Epoch 11/20
# 173/173 [==============================] - 369s 2s/step - loss: 3.0363 - accuracy: 0.1374 - val_loss: 3.1935 - val_accuracy: 0.1615
# Epoch 12/20
# 173/173 [==============================] - 370s 2s/step - loss: 3.0136 - accuracy: 0.1438 - val_loss: 3.1341 - val_accuracy: 0.1553
# Epoch 13/20
# 173/173 [==============================] - 374s 2s/step - loss: 2.9871 - accuracy: 0.1553 - val_loss: 3.1150 - val_accuracy: 0.1429
# Epoch 14/20
# 173/173 [==============================] - 377s 2s/step - loss: 2.9663 - accuracy: 0.1635 - val_loss: 3.1545 - val_accuracy: 0.1677
# Epoch 15/20
# 173/173 [==============================] - 375s 2s/step - loss: 2.9504 - accuracy: 0.1682 - val_loss: 3.0319 - val_accuracy: 0.1615
# Epoch 16/20
# 173/173 [==============================] - 375s 2s/step - loss: 2.9344 - accuracy: 0.1724 - val_loss: 3.0685 - val_accuracy: 0.1739
# Epoch 17/20
# 173/173 [==============================] - 376s 2s/step - loss: 2.9119 - accuracy: 0.1796 - val_loss: 3.0592 - val_accuracy: 0.1863
# Epoch 18/20
# 173/173 [==============================] - 377s 2s/step - loss: 2.9054 - accuracy: 0.1785 - val_loss: 2.9606 - val_accuracy: 0.2174
# Epoch 19/20
# 173/173 [==============================] - 376s 2s/step - loss: 2.8827 - accuracy: 0.1838 - val_loss: 3.0011 - val_accuracy: 0.1863
# Epoch 20/20
# 173/173 [==============================] - 375s 2s/step - loss: 2.8655 - accuracy: 0.1911 - val_loss: 3.0580 - val_accuracy: 0.1863

# %% [markdown]
# ## Plotting Graphs

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_2.history.values())[0])
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.title('Training loss over 20 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_2.history.values())[1])
plt.xlabel('epoch')
plt.ylabel('training accuracy')
plt.title('Training accuracy over 20 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_2.history.values())[2])
plt.xlabel('epoch')
plt.ylabel('validation loss')
plt.title('Validation loss over 20 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_2.history.values())[3])
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.title('Validation accuracy over 20 epochs')
plt.show()

# %% [markdown]
# # RNN 2

# %%
model = create_network(network_input_train, n_vocab)
filepath = "/content/drive/My Drive/nes/check/4/weights-{epoch:02d}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
print(model.summary())
hist_3 = model.fit(network_input_train, network_output_train, epochs = 50,
            validation_data = (network_input_val, network_output_val), 
            batch_size = 128, callbacks=callbacks_list)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_8 (SimpleRNN)     (None, 100, 512)          263168
# _________________________________________________________________
# simple_rnn_9 (SimpleRNN)     (None, 100, 512)          524800
# _________________________________________________________________
# simple_rnn_10 (SimpleRNN)    (None, 100, 512)          524800
# _________________________________________________________________
# simple_rnn_11 (SimpleRNN)    (None, 512)               524800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_6 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_8 (Dense)              (None, 400)               205200
# _________________________________________________________________
# activation_8 (Activation)    (None, 400)               0
# =================================================================
# Total params: 2,572,176
# Trainable params: 2,570,128
# Non-trainable params: 2,048
# _________________________________________________________________
# None
# Epoch 1/50
# 173/173 [==============================] - 115s 642ms/step - loss: 5.1855 - accuracy: 0.0360 - val_loss: 4.2231 - val_accuracy: 0.0497
# Epoch 2/50
# 173/173 [==============================] - 110s 637ms/step - loss: 3.9066 - accuracy: 0.0554 - val_loss: 4.0880 - val_accuracy: 0.0621
# Epoch 3/50
# 173/173 [==============================] - 113s 651ms/step - loss: 3.7678 - accuracy: 0.0613 - val_loss: 4.0961 - val_accuracy: 0.0311
# Epoch 4/50
# 173/173 [==============================] - 111s 643ms/step - loss: 3.7188 - accuracy: 0.0638 - val_loss: 4.0755 - val_accuracy: 0.0559
# Epoch 5/50
# 173/173 [==============================] - 112s 645ms/step - loss: 3.6973 - accuracy: 0.0648 - val_loss: 4.0540 - val_accuracy: 0.0248
# Epoch 6/50
# 173/173 [==============================] - 111s 640ms/step - loss: 3.6747 - accuracy: 0.0677 - val_loss: 4.0600 - val_accuracy: 0.0311
# Epoch 7/50
# 173/173 [==============================] - 110s 636ms/step - loss: 3.6687 - accuracy: 0.0681 - val_loss: 3.9741 - val_accuracy: 0.0745
# Epoch 8/50
# 173/173 [==============================] - 109s 631ms/step - loss: 3.6554 - accuracy: 0.0679 - val_loss: 4.0588 - val_accuracy: 0.0621
# Epoch 9/50
# 173/173 [==============================] - 110s 633ms/step - loss: 3.6550 - accuracy: 0.0707 - val_loss: 4.0984 - val_accuracy: 0.0248
# Epoch 10/50
# 173/173 [==============================] - 109s 629ms/step - loss: 3.6496 - accuracy: 0.0683 - val_loss: 4.1218 - val_accuracy: 0.0248
# Epoch 11/50
# 173/173 [==============================] - 109s 630ms/step - loss: 3.6492 - accuracy: 0.0698 - val_loss: 4.1099 - val_accuracy: 0.0248
# Epoch 12/50
# 173/173 [==============================] - 109s 628ms/step - loss: 3.6385 - accuracy: 0.0724 - val_loss: 3.9638 - val_accuracy: 0.0683
# Epoch 13/50
# 173/173 [==============================] - 109s 631ms/step - loss: 3.6240 - accuracy: 0.0723 - val_loss: 3.8687 - val_accuracy: 0.0559
# Epoch 14/50
# 173/173 [==============================] - 109s 630ms/step - loss: 3.6136 - accuracy: 0.0767 - val_loss: 4.0218 - val_accuracy: 0.0932
# Epoch 15/50
# 173/173 [==============================] - 108s 626ms/step - loss: 3.6141 - accuracy: 0.0778 - val_loss: 4.1153 - val_accuracy: 0.0497
# 173/173 [==============================] - 108s 627ms/step - loss: 3.5979 - accuracy: 0.0716 - val_loss: 3.9468 - val_accuracy: 0.0435
# Epoch 36/50
# 173/173 [==============================] - 110s 634ms/step - loss: 3.5977 - accuracy: 0.0756 - val_loss: 4.0027 - val_accuracy: 0.0435
# Epoch 37/50
# 173/173 [==============================] - 110s 637ms/step - loss: 3.6094 - accuracy: 0.0726 - val_loss: 3.9981 - val_accuracy: 0.0435
# Epoch 38/50
# 173/173 [==============================] - 108s 623ms/step - loss: 3.6069 - accuracy: 0.0741 - val_loss: 3.9543 - val_accuracy: 0.0497
# Epoch 39/50
# 173/173 [==============================] - 107s 621ms/step - loss: 3.6026 - accuracy: 0.0764 - val_loss: 3.9621 - val_accuracy: 0.0186
# Epoch 40/50
# 173/173 [==============================] - 107s 617ms/step - loss: 3.6056 - accuracy: 0.0729 - val_loss: 3.9311 - val_accuracy: 0.0497
# Epoch 41/50
# 173/173 [==============================] - 108s 622ms/step - loss: 3.6060 - accuracy: 0.0738 - val_loss: 3.8957 - val_accuracy: 0.0435
# Epoch 42/50
# 173/173 [==============================] - 107s 620ms/step - loss: 3.6035 - accuracy: 0.0727 - val_loss: 3.9052 - val_accuracy: 0.0559
# Epoch 43/50
# 173/173 [==============================] - 108s 623ms/step - loss: 3.6024 - accuracy: 0.0745 - val_loss: 3.9459 - val_accuracy: 0.0311
# Epoch 44/50
# 173/173 [==============================] - 108s 623ms/step - loss: 3.6054 - accuracy: 0.0746 - val_loss: 3.9439 - val_accuracy: 0.0497
# Epoch 45/50
# 173/173 [==============================] - 107s 618ms/step - loss: 3.6030 - accuracy: 0.0742 - val_loss: 3.9097 - val_accuracy: 0.0311
# Epoch 46/50
# 173/173 [==============================] - 107s 618ms/step - loss: 3.6029 - accuracy: 0.0758 - val_loss: 3.9210 - val_accuracy: 0.0497
# Epoch 47/50
# 173/173 [==============================] - 107s 619ms/step - loss: 3.6004 - accuracy: 0.0746 - val_loss: 3.9311 - val_accuracy: 0.0373
# Epoch 48/50
# 173/173 [==============================] - 108s 621ms/step - loss: 3.6074 - accuracy: 0.0734 - val_loss: 3.9315 - val_accuracy: 0.0311
# Epoch 49/50
# 173/173 [==============================] - 108s 622ms/step - loss: 3.6026 - accuracy: 0.0767 - val_loss: 3.9619 - val_accuracy: 0.0311
# Epoch 50/50
# 173/173 [==============================] - 107s 619ms/step - loss: 3.6042 - accuracy: 0.0741 - val_loss: 3.9113 - val_accuracy: 0.0497

# %% [markdown]
# ## Plotting Graphs

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_3.history.values())[0])
plt.xlabel('epoch')
plt.ylabel('training loss')
plt.title('Training loss over 50 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_3.history.values())[1])
plt.xlabel('epoch')
plt.ylabel('training accuracy')
plt.title('Training accuracy over 50 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_3.history.values())[2])
plt.xlabel('epoch')
plt.ylabel('validation loss')
plt.title('Validation loss over 50 epochs')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(list(hist_3.history.values())[3])
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.title('Validation accuracy over 50 epochs')
plt.show()
